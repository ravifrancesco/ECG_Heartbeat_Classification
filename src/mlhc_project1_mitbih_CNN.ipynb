# %%
import pandas as pd
import numpy as np

from keras import optimizers, losses, activations, models
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, GlobalMaxPool1D, GlobalAveragePooling1D, concatenate
from sklearn.metrics import f1_score, accuracy_score

import tensorflow as tf
from keras import Input, Model, layers
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras import losses
from tensorflow import keras
from keras.callbacks import EarlyStopping

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv1D, GlobalAveragePooling1D, MaxPooling1D
from keras import regularizers
from keras.utils import np_utils
from keras import utils
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### CNN MITBIH

# %%
df_train = pd.read_csv("/content/drive/MyDrive/MLHC_PROJECT1/mitbih_train.csv", header=None)
df_train = df_train.sample(frac=1)
df_test = pd.read_csv("/content/drive/MyDrive/MLHC_PROJECT1/mitbih_test.csv", header=None)

y_train = np.array(df_train[187].values).astype(np.int8)
X_train = np.array(df_train[list(range(187))].values)[..., np.newaxis]

y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

# %%
# create the model
model = Sequential()
model.add(Conv1D(128, 55, activation='relu', input_shape=(187, 1)))
model.add(MaxPooling1D(2))
model.add(Dropout(0.1))
model.add(Conv1D(128, 25, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.1))
model.add(Conv1D(128, 10, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.5))
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalAveragePooling1D())
# model.add(Flatten())
model.add(Dense(256, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(5, kernel_initializer='normal', activation='softmax'))

model.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])

file_path = "baseline_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

model.fit(X_train, y_train, epochs=100, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

pred_test = model.predict(X_test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(y_test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(y_test, pred_test)

print("Test accuracy score : %s "% acc)

# %% [markdown]
# ### CNN PTBDB

# %%
df_1 = pd.read_csv("/content/drive/MyDrive/MLHC_PROJECT1/ptbdb_normal.csv", header=None)
df_2 = pd.read_csv("/content/drive/MyDrive/MLHC_PROJECT1/ptbdb_abnormal.csv", header=None)
df = pd.concat([df_1, df_2])

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1337, stratify=df[187])


y_train = np.array(df_train[187].values).astype(np.int8)
X_train = np.array(df_train[list(range(187))].values)[..., np.newaxis]

y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

# %%
# create the model
model = Sequential()
model.add(Conv1D(16, 10, activation='relu', input_shape=(187, 1)))
model.add(MaxPooling1D(2))
model.add(Dropout(0.))
model.add(Conv1D(32, 5, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.2))
model.add(Conv1D(64, 10, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.5))
model.add(Conv1D(128, 2, activation='relu'))
model.add(GlobalAveragePooling1D())
# model.add(Flatten())
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(256, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, kernel_initializer='normal', activation='softmax'))

model.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss=losses.sparse_categorical_crossentropy, metrics=['acc'])

file_path = "baseline_cnn_mitbih.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=10, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint]  # early

model.fit(X_train, y_train, epochs=250, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

pred_test = model.predict(X_test)
pred_test = np.argmax(pred_test, axis=-1)

f1 = f1_score(y_test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(y_test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_48 (Conv1D)          (None, 178, 16)           176
#
#  max_pooling1d_33 (MaxPoolin  (None, 89, 16)           0
#  g1D)
#
#  dropout_64 (Dropout)        (None, 89, 16)            0
#
#  conv1d_49 (Conv1D)          (None, 85, 32)            2592
#
#  max_pooling1d_34 (MaxPoolin  (None, 42, 32)           0
#  g1D)
#
#  dropout_65 (Dropout)        (None, 42, 32)            0
#
#  conv1d_50 (Conv1D)          (None, 33, 64)            20544
#
#  max_pooling1d_35 (MaxPoolin  (None, 16, 64)           0
#  g1D)
#
#  dropout_66 (Dropout)        (None, 16, 64)            0
#
#  conv1d_51 (Conv1D)          (None, 15, 128)           16512
#
#  global_average_pooling1d_10  (None, 128)              0
#   (GlobalAveragePooling1D)
#
#  dense_40 (Dense)            (None, 128)               16512
#
#  dropout_67 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 128)               16512
#
#  dropout_68 (Dropout)        (None, 128)               0
#
#  dense_42 (Dense)            (None, 256)               33024
#
#  dropout_69 (Dropout)        (None, 256)               0
#
#  dense_43 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 106,386
# Trainable params: 106,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
#
# Epoch 1: val_acc improved from -inf to 0.73991, saving model to baseline_cnn_mitbih.h5
# 328/328 - 5s - loss: 0.5325 - acc: 0.7326 - val_loss: 0.4998 - val_acc: 0.7399 - 5s/epoch - 15ms/step
# Epoch 2/250
#
# Epoch 2: val_acc improved from 0.73991 to 0.75708, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.4629 - acc: 0.7679 - val_loss: 0.4782 - val_acc: 0.7571 - 2s/epoch - 7ms/step
# Epoch 3/250
#
# Epoch 3: val_acc improved from 0.75708 to 0.82060, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.4293 - acc: 0.7994 - val_loss: 0.4032 - val_acc: 0.8206 - 2s/epoch - 7ms/step
# Epoch 4/250
#
# Epoch 4: val_acc improved from 0.82060 to 0.83176, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.3737 - acc: 0.8348 - val_loss: 0.3425 - val_acc: 0.8318 - 2s/epoch - 7ms/step
# Epoch 5/250
#
# Epoch 5: val_acc improved from 0.83176 to 0.90901, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.2932 - acc: 0.8802 - val_loss: 0.2390 - val_acc: 0.9090 - 2s/epoch - 7ms/step
# Epoch 6/250
#
# Epoch 6: val_acc improved from 0.90901 to 0.91416, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.2467 - acc: 0.9070 - val_loss: 0.2206 - val_acc: 0.9142 - 2s/epoch - 7ms/step
# Epoch 7/250
#
# Epoch 7: val_acc improved from 0.91416 to 0.94592, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.2066 - acc: 0.9222 - val_loss: 0.1549 - val_acc: 0.9459 - 2s/epoch - 7ms/step
# Epoch 8/250
#
# Epoch 8: val_acc did not improve from 0.94592
# 328/328 - 2s - loss: 0.1877 - acc: 0.9303 - val_loss: 0.1604 - val_acc: 0.9365 - 2s/epoch - 7ms/step
# Epoch 9/250
#
# Epoch 9: val_acc did not improve from 0.94592
# 328/328 - 2s - loss: 0.1828 - acc: 0.9325 - val_loss: 0.1605 - val_acc: 0.9382 - 2s/epoch - 7ms/step
# Epoch 10/250
#
# Epoch 10: val_acc did not improve from 0.94592
# 328/328 - 2s - loss: 0.1598 - acc: 0.9404 - val_loss: 0.1819 - val_acc: 0.9391 - 2s/epoch - 7ms/step
# Epoch 11/250
#
# Epoch 11: val_acc improved from 0.94592 to 0.95794, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.1432 - acc: 0.9471 - val_loss: 0.1141 - val_acc: 0.9579 - 2s/epoch - 7ms/step
# Epoch 12/250
#
# Epoch 12: val_acc did not improve from 0.95794
# 328/328 - 2s - loss: 0.1337 - acc: 0.9506 - val_loss: 0.1239 - val_acc: 0.9511 - 2s/epoch - 7ms/step
# Epoch 13/250
#
# Epoch 13: val_acc improved from 0.95794 to 0.96824, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.1229 - acc: 0.9537 - val_loss: 0.0956 - val_acc: 0.9682 - 2s/epoch - 7ms/step
# Epoch 14/250
#
# Epoch 14: val_acc did not improve from 0.96824
# 328/328 - 2s - loss: 0.1158 - acc: 0.9581 - val_loss: 0.0950 - val_acc: 0.9639 - 2s/epoch - 7ms/step
# Epoch 15/250
#
# Epoch 15: val_acc did not improve from 0.96824
# 328/328 - 2s - loss: 0.1110 - acc: 0.9573 - val_loss: 0.1314 - val_acc: 0.9459 - 2s/epoch - 7ms/step
# Epoch 16/250
#
# Epoch 16: val_acc improved from 0.96824 to 0.97167, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.1060 - acc: 0.9614 - val_loss: 0.0720 - val_acc: 0.9717 - 2s/epoch - 7ms/step
# Epoch 17/250
#
# Epoch 17: val_acc did not improve from 0.97167
# 328/328 - 2s - loss: 0.0975 - acc: 0.9645 - val_loss: 0.1000 - val_acc: 0.9700 - 2s/epoch - 7ms/step
# Epoch 18/250
#
# Epoch 18: val_acc did not improve from 0.97167
# 328/328 - 2s - loss: 0.0901 - acc: 0.9661 - val_loss: 0.0993 - val_acc: 0.9639 - 2s/epoch - 7ms/step
# Epoch 19/250
#
# Epoch 19: val_acc improved from 0.97167 to 0.97682, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0924 - acc: 0.9658 - val_loss: 0.0721 - val_acc: 0.9768 - 2s/epoch - 8ms/step
# Epoch 20/250
#
# Epoch 20: val_acc improved from 0.97682 to 0.98026, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0927 - acc: 0.9638 - val_loss: 0.0721 - val_acc: 0.9803 - 2s/epoch - 8ms/step
# Epoch 21/250
#
# Epoch 21: val_acc did not improve from 0.98026
# 328/328 - 2s - loss: 0.0827 - acc: 0.9708 - val_loss: 0.0773 - val_acc: 0.9734 - 2s/epoch - 7ms/step
# Epoch 22/250
#
# Epoch 22: val_acc did not improve from 0.98026
# 328/328 - 2s - loss: 0.0878 - acc: 0.9682 - val_loss: 0.0812 - val_acc: 0.9777 - 2s/epoch - 7ms/step
# Epoch 23/250
#
# Epoch 23: val_acc did not improve from 0.98026
# 328/328 - 2s - loss: 0.0767 - acc: 0.9707 - val_loss: 0.0666 - val_acc: 0.9803 - 2s/epoch - 7ms/step
# Epoch 24/250
#
# Epoch 24: val_acc improved from 0.98026 to 0.98369, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0765 - acc: 0.9737 - val_loss: 0.0513 - val_acc: 0.9837 - 2s/epoch - 7ms/step
# Epoch 25/250
#
# Epoch 25: val_acc did not improve from 0.98369
# 328/328 - 2s - loss: 0.0747 - acc: 0.9729 - val_loss: 0.0654 - val_acc: 0.9794 - 2s/epoch - 7ms/step
# Epoch 26/250
#
# Epoch 26: val_acc did not improve from 0.98369
# 328/328 - 2s - loss: 0.0664 - acc: 0.9757 - val_loss: 0.0523 - val_acc: 0.9837 - 2s/epoch - 7ms/step
# Epoch 27/250
#
# Epoch 27: val_acc improved from 0.98369 to 0.98541, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0672 - acc: 0.9765 - val_loss: 0.0454 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 28/250
#
# Epoch 28: val_acc did not improve from 0.98541
# 328/328 - 2s - loss: 0.0688 - acc: 0.9767 - val_loss: 0.0702 - val_acc: 0.9760 - 2s/epoch - 7ms/step
# Epoch 29/250
#
# Epoch 29: val_acc did not improve from 0.98541
# 328/328 - 2s - loss: 0.0662 - acc: 0.9772 - val_loss: 0.0859 - val_acc: 0.9691 - 2s/epoch - 7ms/step
# Epoch 30/250
#
# Epoch 30: val_acc did not improve from 0.98541
# 328/328 - 2s - loss: 0.0657 - acc: 0.9761 - val_loss: 0.0693 - val_acc: 0.9760 - 2s/epoch - 7ms/step
# Epoch 31/250
#
# Epoch 31: val_acc did not improve from 0.98541
# 328/328 - 2s - loss: 0.0547 - acc: 0.9806 - val_loss: 0.0636 - val_acc: 0.9803 - 2s/epoch - 7ms/step
# Epoch 32/250
#
# Epoch 32: val_acc did not improve from 0.98541
# 328/328 - 2s - loss: 0.0549 - acc: 0.9798 - val_loss: 0.0996 - val_acc: 0.9665 - 2s/epoch - 7ms/step
# Epoch 33/250
#
# Epoch 33: val_acc did not improve from 0.98541
# 328/328 - 2s - loss: 0.0609 - acc: 0.9758 - val_loss: 0.0604 - val_acc: 0.9811 - 2s/epoch - 7ms/step
# Epoch 34/250
#
# Epoch 34: val_acc improved from 0.98541 to 0.98884, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0554 - acc: 0.9813 - val_loss: 0.0380 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 35/250
#
# Epoch 35: val_acc did not improve from 0.98884
# 328/328 - 2s - loss: 0.0546 - acc: 0.9813 - val_loss: 0.0567 - val_acc: 0.9820 - 2s/epoch - 7ms/step
# Epoch 36/250
#
# Epoch 36: val_acc improved from 0.98884 to 0.98970, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0555 - acc: 0.9801 - val_loss: 0.0353 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 37/250
#
# Epoch 37: val_acc did not improve from 0.98970
# 328/328 - 2s - loss: 0.0539 - acc: 0.9799 - val_loss: 0.0520 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 38/250
#
# Epoch 38: val_acc did not improve from 0.98970
# 328/328 - 2s - loss: 0.0644 - acc: 0.9775 - val_loss: 0.0509 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 39/250
#
# Epoch 39: val_acc did not improve from 0.98970
# 328/328 - 2s - loss: 0.0527 - acc: 0.9822 - val_loss: 0.0482 - val_acc: 0.9811 - 2s/epoch - 7ms/step
# Epoch 40/250
#
# Epoch 40: val_acc improved from 0.98970 to 0.99056, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0566 - acc: 0.9789 - val_loss: 0.0316 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 41/250
#
# Epoch 41: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0594 - acc: 0.9785 - val_loss: 0.0597 - val_acc: 0.9811 - 2s/epoch - 7ms/step
# Epoch 42/250
#
# Epoch 42: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0459 - acc: 0.9827 - val_loss: 0.0409 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 43/250
#
# Epoch 43: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0545 - acc: 0.9826 - val_loss: 0.0353 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 44/250
#
# Epoch 44: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0446 - acc: 0.9846 - val_loss: 0.0501 - val_acc: 0.9828 - 2s/epoch - 7ms/step
# Epoch 45/250
#
# Epoch 45: val_acc did not improve from 0.99056
# 328/328 - 3s - loss: 0.0584 - acc: 0.9799 - val_loss: 0.0798 - val_acc: 0.9760 - 3s/epoch - 9ms/step
# Epoch 46/250
#
# Epoch 46: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0448 - acc: 0.9860 - val_loss: 0.0329 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 47/250
#
# Epoch 47: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0449 - acc: 0.9836 - val_loss: 0.0468 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 48/250
#
# Epoch 48: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0487 - acc: 0.9820 - val_loss: 0.0626 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 49/250
#
# Epoch 49: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0453 - acc: 0.9832 - val_loss: 0.0436 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 50/250
#
# Epoch 50: val_acc did not improve from 0.99056
# 328/328 - 2s - loss: 0.0460 - acc: 0.9838 - val_loss: 0.0513 - val_acc: 0.9820 - 2s/epoch - 7ms/step
# Epoch 51/250
#
# Epoch 51: val_acc improved from 0.99056 to 0.99227, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0433 - acc: 0.9861 - val_loss: 0.0305 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 52/250
#
# Epoch 52: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0432 - acc: 0.9845 - val_loss: 0.0503 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 53/250
#
# Epoch 53: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0440 - acc: 0.9835 - val_loss: 0.0667 - val_acc: 0.9828 - 2s/epoch - 7ms/step
# Epoch 54/250
#
# Epoch 54: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0434 - acc: 0.9850 - val_loss: 0.0352 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 55/250
#
# Epoch 55: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0427 - acc: 0.9852 - val_loss: 0.0678 - val_acc: 0.9777 - 2s/epoch - 7ms/step
# Epoch 56/250
#
# Epoch 56: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0455 - acc: 0.9833 - val_loss: 0.0548 - val_acc: 0.9820 - 2s/epoch - 7ms/step
# Epoch 57/250
#
# Epoch 57: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0418 - acc: 0.9849 - val_loss: 0.0436 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 58/250
#
# Epoch 58: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0381 - acc: 0.9875 - val_loss: 0.0510 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 59/250
#
# Epoch 59: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0416 - acc: 0.9857 - val_loss: 0.0457 - val_acc: 0.9837 - 2s/epoch - 7ms/step
# Epoch 60/250
#
# Epoch 60: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0414 - acc: 0.9859 - val_loss: 0.0407 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 61/250
#
# Epoch 61: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0451 - acc: 0.9843 - val_loss: 0.0376 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 62/250
#
# Epoch 62: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0395 - acc: 0.9873 - val_loss: 0.0312 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 63/250
#
# Epoch 63: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0343 - acc: 0.9879 - val_loss: 0.0413 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 64/250
#
# Epoch 64: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0409 - acc: 0.9863 - val_loss: 0.0281 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 65/250
#
# Epoch 65: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0340 - acc: 0.9883 - val_loss: 0.0337 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 66/250
#
# Epoch 66: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0316 - acc: 0.9893 - val_loss: 0.0426 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 67/250
#
# Epoch 67: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0376 - acc: 0.9869 - val_loss: 0.0417 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 68/250
#
# Epoch 68: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0376 - acc: 0.9873 - val_loss: 0.0522 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 69/250
#
# Epoch 69: val_acc did not improve from 0.99227
# 328/328 - 3s - loss: 0.0353 - acc: 0.9876 - val_loss: 0.0351 - val_acc: 0.9888 - 3s/epoch - 8ms/step
# Epoch 70/250
#
# Epoch 70: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0315 - acc: 0.9888 - val_loss: 0.0327 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 71/250
#
# Epoch 71: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0293 - acc: 0.9900 - val_loss: 0.0423 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 72/250
#
# Epoch 72: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0354 - acc: 0.9872 - val_loss: 0.0343 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 73/250
#
# Epoch 73: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0340 - acc: 0.9877 - val_loss: 0.0743 - val_acc: 0.9785 - 2s/epoch - 7ms/step
# Epoch 74/250
#
# Epoch 74: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0272 - acc: 0.9901 - val_loss: 0.0296 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 75/250
#
# Epoch 75: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0301 - acc: 0.9898 - val_loss: 0.0483 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 76/250
#
# Epoch 76: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0276 - acc: 0.9915 - val_loss: 0.0539 - val_acc: 0.9803 - 2s/epoch - 7ms/step
# Epoch 77/250
#
# Epoch 77: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0319 - acc: 0.9901 - val_loss: 0.0331 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 78/250
#
# Epoch 78: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0312 - acc: 0.9882 - val_loss: 0.0441 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 79/250
#
# Epoch 79: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0335 - acc: 0.9877 - val_loss: 0.0286 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 80/250
#
# Epoch 80: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0325 - acc: 0.9895 - val_loss: 0.0416 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 81/250
#
# Epoch 81: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0355 - acc: 0.9889 - val_loss: 0.0386 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 82/250
#
# Epoch 82: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0309 - acc: 0.9891 - val_loss: 0.0327 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 83/250
#
# Epoch 83: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0335 - acc: 0.9883 - val_loss: 0.0317 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 84/250
#
# Epoch 84: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0288 - acc: 0.9899 - val_loss: 0.0580 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 85/250
#
# Epoch 85: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0307 - acc: 0.9892 - val_loss: 0.0297 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 86/250
#
# Epoch 86: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0257 - acc: 0.9914 - val_loss: 0.0443 - val_acc: 0.9837 - 2s/epoch - 7ms/step
# Epoch 87/250
#
# Epoch 87: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0301 - acc: 0.9893 - val_loss: 0.0382 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 88/250
#
# Epoch 88: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0287 - acc: 0.9901 - val_loss: 0.0424 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 89/250
#
# Epoch 89: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0277 - acc: 0.9904 - val_loss: 0.0384 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 90/250
#
# Epoch 90: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0314 - acc: 0.9907 - val_loss: 0.0450 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 91/250
#
# Epoch 91: val_acc did not improve from 0.99227
# 328/328 - 2s - loss: 0.0323 - acc: 0.9888 - val_loss: 0.0298 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 92/250
#
# Epoch 92: val_acc improved from 0.99227 to 0.99399, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0254 - acc: 0.9909 - val_loss: 0.0301 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 93/250
#
# Epoch 93: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0270 - acc: 0.9907 - val_loss: 0.0427 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 94/250
#
# Epoch 94: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0292 - acc: 0.9912 - val_loss: 0.0363 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 95/250
#
# Epoch 95: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0296 - acc: 0.9898 - val_loss: 0.0495 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 96/250
#
# Epoch 96: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0350 - acc: 0.9893 - val_loss: 0.0219 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 97/250
#
# Epoch 97: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0222 - acc: 0.9927 - val_loss: 0.0590 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 98/250
#
# Epoch 98: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0295 - acc: 0.9910 - val_loss: 0.0250 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 99/250
#
# Epoch 99: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0242 - acc: 0.9912 - val_loss: 0.0346 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 100/250
#
# Epoch 100: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0252 - acc: 0.9916 - val_loss: 0.0269 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 101/250
#
# Epoch 101: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0243 - acc: 0.9909 - val_loss: 0.0357 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 102/250
#
# Epoch 102: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0246 - acc: 0.9919 - val_loss: 0.0635 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 103/250
#
# Epoch 103: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0308 - acc: 0.9889 - val_loss: 0.0481 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 104/250
#
# Epoch 104: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0273 - acc: 0.9889 - val_loss: 0.0315 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 105/250
#
# Epoch 105: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0318 - acc: 0.9902 - val_loss: 0.0289 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 106/250
#
# Epoch 106: val_acc did not improve from 0.99399
# 328/328 - 2s - loss: 0.0276 - acc: 0.9901 - val_loss: 0.0230 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 107/250
#
# Epoch 107: val_acc improved from 0.99399 to 0.99571, saving model to baseline_cnn_mitbih.h5
# 328/328 - 2s - loss: 0.0203 - acc: 0.9927 - val_loss: 0.0211 - val_acc: 0.9957 - 2s/epoch - 7ms/step
# Epoch 108/250
#
# Epoch 108: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0241 - acc: 0.9920 - val_loss: 0.0318 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 109/250
#
# Epoch 109: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0296 - acc: 0.9903 - val_loss: 0.0424 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 110/250
#
# Epoch 110: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0200 - acc: 0.9924 - val_loss: 0.0433 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 111/250
#
# Epoch 111: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0273 - acc: 0.9911 - val_loss: 0.0330 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 112/250
#
# Epoch 112: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0277 - acc: 0.9911 - val_loss: 0.0485 - val_acc: 0.9811 - 2s/epoch - 7ms/step
# Epoch 113/250
#
# Epoch 113: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0198 - acc: 0.9932 - val_loss: 0.0369 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 114/250
#
# Epoch 114: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0232 - acc: 0.9926 - val_loss: 0.0376 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 115/250
#
# Epoch 115: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0279 - acc: 0.9910 - val_loss: 0.0497 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 116/250
#
# Epoch 116: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0233 - acc: 0.9918 - val_loss: 0.0635 - val_acc: 0.9845 - 2s/epoch - 7ms/step
# Epoch 117/250
#
# Epoch 117: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0227 - acc: 0.9928 - val_loss: 0.0426 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 118/250
#
# Epoch 118: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0251 - acc: 0.9922 - val_loss: 0.0830 - val_acc: 0.9777 - 2s/epoch - 7ms/step
# Epoch 119/250
#
# Epoch 119: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0285 - acc: 0.9900 - val_loss: 0.0363 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 120/250
#
# Epoch 120: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0177 - acc: 0.9937 - val_loss: 0.0392 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 121/250
#
# Epoch 121: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0251 - acc: 0.9915 - val_loss: 0.0312 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 122/250
#
# Epoch 122: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0244 - acc: 0.9909 - val_loss: 0.0669 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 123/250
#
# Epoch 123: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0205 - acc: 0.9924 - val_loss: 0.0554 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 124/250
#
# Epoch 124: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0240 - acc: 0.9920 - val_loss: 0.0414 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 125/250
#
# Epoch 125: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0193 - acc: 0.9935 - val_loss: 0.0315 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 126/250
#
# Epoch 126: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0203 - acc: 0.9932 - val_loss: 0.0365 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 127/250
#
# Epoch 127: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0198 - acc: 0.9927 - val_loss: 0.0318 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 128/250
#
# Epoch 128: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0211 - acc: 0.9921 - val_loss: 0.0412 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 129/250
#
# Epoch 129: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0201 - acc: 0.9937 - val_loss: 0.0243 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 130/250
#
# Epoch 130: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0259 - acc: 0.9909 - val_loss: 0.0241 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 131/250
#
# Epoch 131: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0205 - acc: 0.9920 - val_loss: 0.0268 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 132/250
#
# Epoch 132: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0212 - acc: 0.9921 - val_loss: 0.0496 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 133/250
#
# Epoch 133: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0196 - acc: 0.9942 - val_loss: 0.0246 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 134/250
#
# Epoch 134: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0199 - acc: 0.9933 - val_loss: 0.0313 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 135/250
#
# Epoch 135: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0172 - acc: 0.9947 - val_loss: 0.0534 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 136/250
#
# Epoch 136: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0229 - acc: 0.9925 - val_loss: 0.0273 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 137/250
#
# Epoch 137: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0218 - acc: 0.9926 - val_loss: 0.0399 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 138/250
#
# Epoch 138: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0306 - acc: 0.9908 - val_loss: 0.0402 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 139/250
#
# Epoch 139: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0192 - acc: 0.9943 - val_loss: 0.0291 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 140/250
#
# Epoch 140: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0242 - acc: 0.9924 - val_loss: 0.0298 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 141/250
#
# Epoch 141: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0185 - acc: 0.9948 - val_loss: 0.0225 - val_acc: 0.9948 - 2s/epoch - 7ms/step
# Epoch 142/250
#
# Epoch 142: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0192 - acc: 0.9932 - val_loss: 0.0498 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 143/250
#
# Epoch 143: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0205 - acc: 0.9928 - val_loss: 0.0336 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 144/250
#
# Epoch 144: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0226 - acc: 0.9928 - val_loss: 0.0334 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 145/250
#
# Epoch 145: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0203 - acc: 0.9926 - val_loss: 0.0320 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 146/250
#
# Epoch 146: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0178 - acc: 0.9939 - val_loss: 0.0503 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 147/250
#
# Epoch 147: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0221 - acc: 0.9926 - val_loss: 0.0344 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 148/250
#
# Epoch 148: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0186 - acc: 0.9939 - val_loss: 0.0294 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 149/250
#
# Epoch 149: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0217 - acc: 0.9938 - val_loss: 0.0382 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 150/250
#
# Epoch 150: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0201 - acc: 0.9935 - val_loss: 0.0441 - val_acc: 0.9845 - 2s/epoch - 7ms/step
# Epoch 151/250
#
# Epoch 151: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0207 - acc: 0.9931 - val_loss: 0.0276 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 152/250
#
# Epoch 152: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0179 - acc: 0.9938 - val_loss: 0.0352 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 153/250
#
# Epoch 153: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0244 - acc: 0.9926 - val_loss: 0.0371 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 154/250
#
# Epoch 154: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0226 - acc: 0.9920 - val_loss: 0.0570 - val_acc: 0.9863 - 2s/epoch - 7ms/step
# Epoch 155/250
#
# Epoch 155: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0171 - acc: 0.9942 - val_loss: 0.0387 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 156/250
#
# Epoch 156: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0189 - acc: 0.9952 - val_loss: 0.0288 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 157/250
#
# Epoch 157: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0236 - acc: 0.9926 - val_loss: 0.0246 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 158/250
#
# Epoch 158: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0178 - acc: 0.9942 - val_loss: 0.0486 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 159/250
#
# Epoch 159: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0147 - acc: 0.9956 - val_loss: 0.0382 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 160/250
#
# Epoch 160: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0264 - acc: 0.9908 - val_loss: 0.0330 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 161/250
#
# Epoch 161: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0181 - acc: 0.9939 - val_loss: 0.0236 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 162/250
#
# Epoch 162: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0204 - acc: 0.9938 - val_loss: 0.0220 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 163/250
#
# Epoch 163: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0208 - acc: 0.9931 - val_loss: 0.0283 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 164/250
#
# Epoch 164: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0186 - acc: 0.9940 - val_loss: 0.0366 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 165/250
#
# Epoch 165: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0160 - acc: 0.9941 - val_loss: 0.0433 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 166/250
#
# Epoch 166: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0142 - acc: 0.9948 - val_loss: 0.0523 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 167/250
#
# Epoch 167: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0243 - acc: 0.9925 - val_loss: 0.0263 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 168/250
#
# Epoch 168: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0199 - acc: 0.9930 - val_loss: 0.0378 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 169/250
#
# Epoch 169: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0162 - acc: 0.9945 - val_loss: 0.0264 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 170/250
#
# Epoch 170: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0193 - acc: 0.9947 - val_loss: 0.0350 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 171/250
#
# Epoch 171: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0194 - acc: 0.9936 - val_loss: 0.0524 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 172/250
#
# Epoch 172: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0167 - acc: 0.9940 - val_loss: 0.0215 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 173/250
#
# Epoch 173: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0131 - acc: 0.9961 - val_loss: 0.0322 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 174/250
#
# Epoch 174: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0209 - acc: 0.9934 - val_loss: 0.0260 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 175/250
#
# Epoch 175: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0218 - acc: 0.9926 - val_loss: 0.0395 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 176/250
#
# Epoch 176: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0131 - acc: 0.9957 - val_loss: 0.0265 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 177/250
#
# Epoch 177: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0195 - acc: 0.9941 - val_loss: 0.0258 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 178/250
#
# Epoch 178: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0188 - acc: 0.9934 - val_loss: 0.0301 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 179/250
#
# Epoch 179: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0177 - acc: 0.9947 - val_loss: 0.0368 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 180/250
#
# Epoch 180: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0172 - acc: 0.9942 - val_loss: 0.0271 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 181/250
#
# Epoch 181: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0142 - acc: 0.9955 - val_loss: 0.0308 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 182/250
#
# Epoch 182: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0188 - acc: 0.9939 - val_loss: 0.0275 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 183/250
#
# Epoch 183: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0170 - acc: 0.9942 - val_loss: 0.0325 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 184/250
#
# Epoch 184: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0177 - acc: 0.9946 - val_loss: 0.0471 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 185/250
#
# Epoch 185: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0214 - acc: 0.9937 - val_loss: 0.0279 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 186/250
#
# Epoch 186: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0197 - acc: 0.9932 - val_loss: 0.0302 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 187/250
#
# Epoch 187: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0174 - acc: 0.9941 - val_loss: 0.0213 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 188/250
#
# Epoch 188: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0120 - acc: 0.9960 - val_loss: 0.0381 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 189/250
#
# Epoch 189: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0195 - acc: 0.9941 - val_loss: 0.0196 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 190/250
#
# Epoch 190: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0147 - acc: 0.9953 - val_loss: 0.0300 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 191/250
#
# Epoch 191: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0239 - acc: 0.9926 - val_loss: 0.0203 - val_acc: 0.9948 - 2s/epoch - 7ms/step
# Epoch 192/250
#
# Epoch 192: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0121 - acc: 0.9961 - val_loss: 0.0357 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 193/250
#
# Epoch 193: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0224 - acc: 0.9939 - val_loss: 0.0200 - val_acc: 0.9948 - 2s/epoch - 7ms/step
# Epoch 194/250
#
# Epoch 194: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0158 - acc: 0.9937 - val_loss: 0.0733 - val_acc: 0.9845 - 2s/epoch - 7ms/step
# Epoch 195/250
#
# Epoch 195: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0208 - acc: 0.9934 - val_loss: 0.0308 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 196/250
#
# Epoch 196: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0186 - acc: 0.9941 - val_loss: 0.0275 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 197/250
#
# Epoch 197: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0189 - acc: 0.9931 - val_loss: 0.0204 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 198/250
#
# Epoch 198: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0194 - acc: 0.9935 - val_loss: 0.0274 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 199/250
#
# Epoch 199: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0117 - acc: 0.9963 - val_loss: 0.0536 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 200/250
#
# Epoch 200: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0142 - acc: 0.9943 - val_loss: 0.0641 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 201/250
#
# Epoch 201: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0158 - acc: 0.9948 - val_loss: 0.0312 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 202/250
#
# Epoch 202: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0150 - acc: 0.9951 - val_loss: 0.0477 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 203/250
#
# Epoch 203: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0136 - acc: 0.9946 - val_loss: 0.0438 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 204/250
#
# Epoch 204: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0175 - acc: 0.9939 - val_loss: 0.0322 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 205/250
#
# Epoch 205: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0159 - acc: 0.9947 - val_loss: 0.0466 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 206/250
#
# Epoch 206: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0212 - acc: 0.9929 - val_loss: 0.0211 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 207/250
#
# Epoch 207: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0135 - acc: 0.9947 - val_loss: 0.0351 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 208/250
#
# Epoch 208: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0185 - acc: 0.9948 - val_loss: 0.0242 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 209/250
#
# Epoch 209: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0170 - acc: 0.9942 - val_loss: 0.0210 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 210/250
#
# Epoch 210: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0146 - acc: 0.9960 - val_loss: 0.0437 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 211/250
#
# Epoch 211: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0115 - acc: 0.9958 - val_loss: 0.0242 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 212/250
#
# Epoch 212: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0190 - acc: 0.9932 - val_loss: 0.0400 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 213/250
#
# Epoch 213: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0127 - acc: 0.9953 - val_loss: 0.0209 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 214/250
#
# Epoch 214: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0157 - acc: 0.9951 - val_loss: 0.0436 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 215/250
#
# Epoch 215: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0152 - acc: 0.9949 - val_loss: 0.0370 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 216/250
#
# Epoch 216: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0132 - acc: 0.9957 - val_loss: 0.0277 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 217/250
#
# Epoch 217: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0170 - acc: 0.9947 - val_loss: 0.0283 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 218/250
#
# Epoch 218: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0142 - acc: 0.9952 - val_loss: 0.0355 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 219/250
#
# Epoch 219: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0121 - acc: 0.9957 - val_loss: 0.0503 - val_acc: 0.9854 - 2s/epoch - 7ms/step
# Epoch 220/250
#
# Epoch 220: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0186 - acc: 0.9935 - val_loss: 0.0430 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 221/250
#
# Epoch 221: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0128 - acc: 0.9961 - val_loss: 0.0219 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 222/250
#
# Epoch 222: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0129 - acc: 0.9960 - val_loss: 0.0226 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 223/250
#
# Epoch 223: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0157 - acc: 0.9954 - val_loss: 0.0296 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 224/250
#
# Epoch 224: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0128 - acc: 0.9961 - val_loss: 0.0334 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 225/250
#
# Epoch 225: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0174 - acc: 0.9946 - val_loss: 0.0369 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 226/250
#
# Epoch 226: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0155 - acc: 0.9946 - val_loss: 0.0454 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 227/250
#
# Epoch 227: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0142 - acc: 0.9955 - val_loss: 0.0225 - val_acc: 0.9957 - 2s/epoch - 7ms/step
# Epoch 228/250
#
# Epoch 228: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0127 - acc: 0.9964 - val_loss: 0.0345 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 229/250
#
# Epoch 229: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0155 - acc: 0.9947 - val_loss: 0.0401 - val_acc: 0.9880 - 2s/epoch - 7ms/step
# Epoch 230/250
#
# Epoch 230: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0189 - acc: 0.9938 - val_loss: 0.0229 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 231/250
#
# Epoch 231: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0134 - acc: 0.9959 - val_loss: 0.0576 - val_acc: 0.9871 - 2s/epoch - 7ms/step
# Epoch 232/250
#
# Epoch 232: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0133 - acc: 0.9956 - val_loss: 0.0329 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 233/250
#
# Epoch 233: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0148 - acc: 0.9951 - val_loss: 0.0430 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 234/250
#
# Epoch 234: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0150 - acc: 0.9952 - val_loss: 0.0243 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 235/250
#
# Epoch 235: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0196 - acc: 0.9946 - val_loss: 0.0228 - val_acc: 0.9940 - 2s/epoch - 7ms/step
# Epoch 236/250
#
# Epoch 236: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0115 - acc: 0.9961 - val_loss: 0.0258 - val_acc: 0.9914 - 2s/epoch - 7ms/step
# Epoch 237/250
#
# Epoch 237: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0089 - acc: 0.9964 - val_loss: 0.0523 - val_acc: 0.9888 - 2s/epoch - 7ms/step
# Epoch 238/250
#
# Epoch 238: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0154 - acc: 0.9948 - val_loss: 0.0346 - val_acc: 0.9948 - 2s/epoch - 7ms/step
# Epoch 239/250
#
# Epoch 239: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0168 - acc: 0.9952 - val_loss: 0.0204 - val_acc: 0.9957 - 2s/epoch - 7ms/step
# Epoch 240/250
#
# Epoch 240: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0112 - acc: 0.9968 - val_loss: 0.0273 - val_acc: 0.9948 - 2s/epoch - 7ms/step
# Epoch 241/250
#
# Epoch 241: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0148 - acc: 0.9951 - val_loss: 0.0338 - val_acc: 0.9906 - 2s/epoch - 7ms/step
# Epoch 242/250
#
# Epoch 242: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0173 - acc: 0.9947 - val_loss: 0.0168 - val_acc: 0.9957 - 2s/epoch - 7ms/step
# Epoch 243/250
#
# Epoch 243: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0103 - acc: 0.9957 - val_loss: 0.0347 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 244/250
#
# Epoch 244: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0153 - acc: 0.9958 - val_loss: 0.0353 - val_acc: 0.9923 - 2s/epoch - 7ms/step
# Epoch 245/250
#
# Epoch 245: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0287 - acc: 0.9899 - val_loss: 0.0319 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 246/250
#
# Epoch 246: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0135 - acc: 0.9953 - val_loss: 0.0340 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 247/250
#
# Epoch 247: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0144 - acc: 0.9955 - val_loss: 0.0308 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Epoch 248/250
#
# Epoch 248: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0149 - acc: 0.9959 - val_loss: 0.0357 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 249/250
#
# Epoch 249: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0144 - acc: 0.9949 - val_loss: 0.0380 - val_acc: 0.9897 - 2s/epoch - 7ms/step
# Epoch 250/250
#
# Epoch 250: val_acc did not improve from 0.99571
# 328/328 - 2s - loss: 0.0092 - acc: 0.9961 - val_loss: 0.0364 - val_acc: 0.9931 - 2s/epoch - 7ms/step
# Test f1 score : 0.9935830711232029
# Test accuracy score : 0.9948471315699072
