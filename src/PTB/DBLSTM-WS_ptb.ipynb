# %% [markdown]
# <a href="https://colab.research.google.com/github/ravifrancesco/ECG_Heartbeat_Classification/blob/dblstm-ws-ptb/DBLSTM-WS_ptb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook parameters

# %%
use_tpu = False
train = False

# %% [markdown]
# 1) Checking resources

# %%
if use_tpu:
  # %tensorflow_version 2.x
  import tensorflow as tf
  print("Tensorflow version " + tf.__version__)

  try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
  except ValueError:
    raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

  tf.config.experimental_connect_to_cluster(tpu)
  tf.tpu.experimental.initialize_tpu_system(tpu)
  tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# 2) Setting up colab

# %%
# Gloabal variables
data_path = "../input/"
model_path = "../../H5/PTB/DBLSTM-WS_ptb.h5"

random_seed = 50

# %%
# Mount Google Drive and set data paths.
import os
from google.colab import drive
from google.colab import files

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 3) Imports

# %%
import pandas as pd
import numpy as np
import itertools

import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score, RocCurveDisplay, average_precision_score, PrecisionRecallDisplay, auc

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

from collections import Counter

import pywt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, optimizers, losses
from tensorflow.keras.layers import Input, LSTM, Dense, Bidirectional, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14486208490081790426
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14465892352
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 498211212007636983
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# Default GPU Device: /device:GPU:0

# %% [markdown]
# 4) Loading data

# %%
df_1 = pd.read_csv(data_path + "ptbdb_normal.csv", header=None)
df_2 = pd.read_csv(data_path + "ptbdb_abnormal.csv", header=None)
df = pd.concat([df_1, df_2])

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1337, stratify=df[187])

Y_train = np.array(df_train[187].values).astype(np.int8)
X_train = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

print("X_train shape is {}".format(X_train.shape))
print("Y_train shape is {}".format(Y_train.shape))
print("X_test shape is {}".format(X_test.shape))
print("Y_test shape is {}".format(Y_test.shape))
# Out:
# X_train shape is (11641, 187, 1)
# Y_train shape is (11641,)
# X_test shape is (2911, 187, 1)
# Y_test shape is (2911,)

# %%
X_train = np.squeeze(X_train)
Y_train = np.squeeze(Y_train)
X_test = np.squeeze(X_test)
Y_test = np.squeeze(Y_test)

print("X_train shape is {}".format(X_train.shape))
print("Y_train shape is {}".format(Y_train.shape))
print("X_test shape is {}".format(X_test.shape))
print("Y_test shape is {}".format(Y_test.shape))
# Out:
# X_train shape is (11641, 187)
# Y_train shape is (11641,)
# X_test shape is (2911, 187)
# Y_test shape is (2911,)

# %% [markdown]
# 5) Visualizing data

# %%
# Plotting one signal
example_signal = 56
plt.rcParams['lines.linewidth'] = 3
plt.figure(figsize=(30, 11))
plt.plot(X_train[example_signal])
plt.title("ECG number {} - Class: {}".format(example_signal+1, np.argmax(Y_train[example_signal])), size = 20)
plt.show()

# %% [markdown]
# 6) Building SimpleRNN

# %%
# Discrete wavelet transform multiresolution analysis level by level
coeffs = pywt.wavedec(X_train[example_signal].flatten(), 'db6', mode='symmetric', level=4)[1:]

fig, axs = plt.subplots(4, figsize=(20, 13))
fig.suptitle("ECG number {} - Class: {}".format(example_signal+1, np.argmax(Y_train[example_signal])), size=20)
for i, c in enumerate(coeffs):
  axs[i].plot(c)
  axs[i].set_title("Level {}".format(str(4-i)))

# %%
def DWT(signal, levels):
  coeffs = pywt.wavedec(signal.flatten(), 'db6', mode='symmetric', level=levels)[1:]
  coeffs = [np.pad(np.array(c), (0, 187-len(c))) for c in coeffs]
  coeffs += [signal]
  return np.stack(coeffs, axis=-1)

def WSpreprocess(dataset, levels):
  return np.squeeze(np.apply_along_axis(DWT, 1, dataset, levels))

# %%
X_train = WSpreprocess(X_train, 2)
#X_val = WSpreprocess(X_val, 2)
X_test = WSpreprocess(X_test, 2)

print("X_train shape is {}".format(X_train.shape))
#print("X_val shape is {}".format(X_val.shape))
print("X_test shape is {}".format(X_test.shape))
# Out:
# X_train shape is (11641, 187, 3)
# X_test shape is (2911, 187, 3)

# %%
def getDBLSTMWS(input_shape, lr=0.0005, n_classes=1):

  inp = Input(shape=input_shape)
  img_1 = Bidirectional(LSTM(64, return_sequences=True))(inp)
  img_2 = Dropout(0.01)(img_1)
  img_3 = Bidirectional(LSTM(32, return_sequences=True))(img_2)
  img_4 = Dropout(0.01)(img_3)
  img_5 = Flatten()(img_4)
  img_6 = Dense(128, activation='relu')(img_5)
  img_7 = Dropout(0.3)(img_6)
  out = Dense(n_classes, activation='sigmoid', use_bias=True)(img_7)

  model = models.Model(inputs=inp, outputs=out)
  opt = optimizers.Adam(learning_rate=lr)
  model.compile(optimizer=opt, loss=losses.BinaryCrossentropy(name='bce', from_logits=False), metrics=['acc'])
  return model

# %%
if use_tpu:
  with tpu_strategy.scope():
    sRNN = getDBLSTMWS(X_train[0].shape, lr=0.001)
else:
    sRNN = getDBLSTMWS(X_train[0].shape, lr=0.001)
    
tf.keras.utils.plot_model(sRNN, show_shapes=True, dpi=64)

# %%
# Preparing the model
sRNN_file_path = model_path
checkpoint = ModelCheckpoint(sRNN_file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early = EarlyStopping(monitor='val_loss', mode="min", patience=10, verbose=1)
redonplat = ReduceLROnPlateau(monitor='val_loss', mode="min", patience=5, verbose=2)
callbacks_list = [early, checkpoint, redonplat]

# %%
# Fitting the model
if train:
  history = sRNN.fit(X_train, Y_train, epochs=1000, verbose=2, callbacks=callbacks_list, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 0.38539, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 12s - loss: 0.4568 - acc: 0.7684 - val_loss: 0.3854 - val_acc: 0.7991 - lr: 0.0010 - 12s/epoch - 167ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.38539 to 0.33065, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.3621 - acc: 0.8237 - val_loss: 0.3307 - val_acc: 0.8334 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.33065 to 0.24008, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.3036 - acc: 0.8649 - val_loss: 0.2401 - val_acc: 0.9085 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.24008 to 0.21975, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.2482 - acc: 0.8955 - val_loss: 0.2198 - val_acc: 0.9197 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.21975 to 0.18017, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.2162 - acc: 0.9108 - val_loss: 0.1802 - val_acc: 0.9360 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.18017 to 0.17226, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.1917 - acc: 0.9211 - val_loss: 0.1723 - val_acc: 0.9339 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.17226 to 0.14659, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.1607 - acc: 0.9361 - val_loss: 0.1466 - val_acc: 0.9450 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.14659
# 73/73 - 3s - loss: 0.1408 - acc: 0.9458 - val_loss: 0.1471 - val_acc: 0.9455 - lr: 0.0010 - 3s/epoch - 34ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 0.14659 to 0.13323, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.1265 - acc: 0.9537 - val_loss: 0.1332 - val_acc: 0.9558 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 0.13323 to 0.12946, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.1210 - acc: 0.9559 - val_loss: 0.1295 - val_acc: 0.9502 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss improved from 0.12946 to 0.11851, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.1054 - acc: 0.9613 - val_loss: 0.1185 - val_acc: 0.9536 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss improved from 0.11851 to 0.09530, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.1043 - acc: 0.9633 - val_loss: 0.0953 - val_acc: 0.9639 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.09530
# 73/73 - 3s - loss: 0.0926 - acc: 0.9665 - val_loss: 0.0955 - val_acc: 0.9691 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 0.09530 to 0.07525, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0774 - acc: 0.9705 - val_loss: 0.0752 - val_acc: 0.9751 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.07525
# 73/73 - 2s - loss: 0.0694 - acc: 0.9727 - val_loss: 0.1042 - val_acc: 0.9682 - lr: 0.0010 - 2s/epoch - 34ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.07525
# 73/73 - 3s - loss: 0.0723 - acc: 0.9741 - val_loss: 0.0896 - val_acc: 0.9721 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss improved from 0.07525 to 0.07376, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0563 - acc: 0.9778 - val_loss: 0.0738 - val_acc: 0.9751 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss improved from 0.07376 to 0.07131, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0530 - acc: 0.9817 - val_loss: 0.0713 - val_acc: 0.9760 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.07131
# 73/73 - 3s - loss: 0.0501 - acc: 0.9820 - val_loss: 0.0722 - val_acc: 0.9734 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.07131
# 73/73 - 2s - loss: 0.0466 - acc: 0.9840 - val_loss: 0.0848 - val_acc: 0.9717 - lr: 0.0010 - 2s/epoch - 34ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.07131
# 73/73 - 3s - loss: 0.0444 - acc: 0.9821 - val_loss: 0.0891 - val_acc: 0.9717 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.07131
# 73/73 - 2s - loss: 0.0539 - acc: 0.9805 - val_loss: 0.0751 - val_acc: 0.9760 - lr: 0.0010 - 2s/epoch - 33ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 0.07131 to 0.05453, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0460 - acc: 0.9836 - val_loss: 0.0545 - val_acc: 0.9833 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.05453
# 73/73 - 2s - loss: 0.0374 - acc: 0.9856 - val_loss: 0.0786 - val_acc: 0.9777 - lr: 0.0010 - 2s/epoch - 34ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.05453
# 73/73 - 2s - loss: 0.0360 - acc: 0.9863 - val_loss: 0.0838 - val_acc: 0.9764 - lr: 0.0010 - 2s/epoch - 34ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.05453
# 73/73 - 2s - loss: 0.0288 - acc: 0.9892 - val_loss: 0.0594 - val_acc: 0.9824 - lr: 0.0010 - 2s/epoch - 34ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.05453
# 73/73 - 2s - loss: 0.0336 - acc: 0.9884 - val_loss: 0.0839 - val_acc: 0.9751 - lr: 0.0010 - 2s/epoch - 34ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.05453
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 73/73 - 3s - loss: 0.0411 - acc: 0.9839 - val_loss: 0.0564 - val_acc: 0.9841 - lr: 0.0010 - 3s/epoch - 34ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss improved from 0.05453 to 0.05225, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0240 - acc: 0.9908 - val_loss: 0.0523 - val_acc: 0.9867 - lr: 1.0000e-04 - 3s/epoch - 41ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss improved from 0.05225 to 0.05210, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0158 - acc: 0.9947 - val_loss: 0.0521 - val_acc: 0.9875 - lr: 1.0000e-04 - 3s/epoch - 35ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss improved from 0.05210 to 0.05022, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_ptb.h5
# 73/73 - 3s - loss: 0.0161 - acc: 0.9943 - val_loss: 0.0502 - val_acc: 0.9858 - lr: 1.0000e-04 - 3s/epoch - 35ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.05022
# 73/73 - 3s - loss: 0.0136 - acc: 0.9955 - val_loss: 0.0512 - val_acc: 0.9871 - lr: 1.0000e-04 - 3s/epoch - 35ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 0.05022
# 73/73 - 2s - loss: 0.0148 - acc: 0.9951 - val_loss: 0.0507 - val_acc: 0.9863 - lr: 1.0000e-04 - 2s/epoch - 34ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 0.05022
# 73/73 - 2s - loss: 0.0110 - acc: 0.9968 - val_loss: 0.0517 - val_acc: 0.9858 - lr: 1.0000e-04 - 2s/epoch - 34ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 0.05022
# 73/73 - 2s - loss: 0.0123 - acc: 0.9958 - val_loss: 0.0526 - val_acc: 0.9850 - lr: 1.0000e-04 - 2s/epoch - 34ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.05022
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 73/73 - 3s - loss: 0.0104 - acc: 0.9969 - val_loss: 0.0527 - val_acc: 0.9871 - lr: 1.0000e-04 - 3s/epoch - 34ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.05022
# 73/73 - 3s - loss: 0.0103 - acc: 0.9972 - val_loss: 0.0518 - val_acc: 0.9867 - lr: 1.0000e-05 - 3s/epoch - 36ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 0.05022
# 73/73 - 3s - loss: 0.0109 - acc: 0.9967 - val_loss: 0.0510 - val_acc: 0.9863 - lr: 1.0000e-05 - 3s/epoch - 35ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.05022
# 73/73 - 2s - loss: 0.0108 - acc: 0.9966 - val_loss: 0.0513 - val_acc: 0.9863 - lr: 1.0000e-05 - 2s/epoch - 34ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.05022
# 73/73 - 2s - loss: 0.0104 - acc: 0.9974 - val_loss: 0.0512 - val_acc: 0.9867 - lr: 1.0000e-05 - 2s/epoch - 34ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.05022
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 73/73 - 2s - loss: 0.0117 - acc: 0.9965 - val_loss: 0.0512 - val_acc: 0.9867 - lr: 1.0000e-05 - 2s/epoch - 34ms/step
# Epoch 41: early stopping

# %%
# Plot training & validation loss values
if train:
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model BCE')
    plt.ylabel('BCE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
# Plot training & validation accuracy values
if train:
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
# Analysis of the model
sRNN.load_weights(sRNN_file_path)
Y_pred_test = sRNN.predict(X_test)
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
print("Model BCE: {}".format(bce(Y_test,Y_pred_test.flatten()).numpy()))
m = tf.keras.metrics.Accuracy()
m.update_state(Y_test.reshape(-1,1), Y_pred_test > 0.5)
print("Model accuracy: {}".format(m.result().numpy()))
# Out:
# Model BCE: 0.42754268646240234
# Model accuracy: 0.9869460463523865

# %%
RocCurveDisplay.from_predictions(Y_test.reshape(-1,1), Y_pred_test)
print("Model AUROC: {}".format(roc_auc_score(Y_test.reshape(-1,1), Y_pred_test, average=None)))
# Out:
# Model AUROC: 0.9958697879116833

# %%
PrecisionRecallDisplay.from_predictions(Y_test.reshape(-1,1), Y_pred_test)
print("Model AUPRC: {}".format(average_precision_score(Y_test.reshape(-1,1), Y_pred_test)))
# Out:
# Model AUPRC: 0.9973379516673074
