# %% [markdown]
# 1) Checking resources

# %%
# !nvidia-smi
# Out:
# Mon Mar 14 15:34:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# 2) Setting up colab

# %%
# Gloabal variables
data_path = "/content/gdrive/My Drive/ETH/MLH/Project1/data/"
model_path = "/content/gdrive/My Drive/ETH/MLH/Project1/model/"

random_seed = 50

# %%
# Mount Google Drive and set data paths.
import os
from google.colab import drive
from google.colab import files

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 3) Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, optimizers, losses
from tensorflow.keras.layers import Input, SimpleRNN, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# 4) Loading data

# %%
df_train = pd.read_csv(data_path + "input/mitbih_train.csv", header=None)
df_train = df_train.sample(frac=1)
df_test = pd.read_csv(data_path + "input/mitbih_test.csv", header=None)

Y = np.array(df_train[187].values).astype(np.int8)
Y = tf.keras.utils.to_categorical(Y)
X = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
Y_test = tf.keras.utils.to_categorical(Y_test)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

print("X shape is {}".format(X.shape))
print("Y shape is {}".format(Y.shape))
print("X_test shape is {}".format(X_test.shape))
print("Y_test shape is {}".format(Y_test.shape))
# Out:
# X shape is (87554, 187, 1)
# Y shape is (87554, 5)
# X_test shape is (21892, 187, 1)
# Y_test shape is (21892, 5)

# %% [markdown]
# 5) Visualizing data

# %%
# Plotting one signal
example_signal = 56
plt.rcParams['lines.linewidth'] = 3
plt.figure(figsize=(30, 11))
plt.plot(X[example_signal])
plt.title("ECG number {} - Class: {}".format(example_signal+1, np.argmax(Y[example_signal])), size = 20)
plt.show()

# %% [markdown]
# 6) Creating validation set

# %%
# Splitting dataset for validation
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=random_seed)
for train_index, test_index in sss.split(X, Y):
    X_train, X_val = X[train_index], X[test_index]
    Y_train, Y_val = Y[train_index], Y[test_index]

print("X_train shape is {}".format(X_train.shape))
print("Y_train shape is {}".format(Y_train.shape))
print("X_val shape is {}".format(X_val.shape))
print("Y_val shape is {}".format(Y_val.shape))
# Out:
# X_train shape is (70043, 187, 1)
# Y_train shape is (70043, 5)
# X_val shape is (17511, 187, 1)
# Y_val shape is (17511, 5)

# %% [markdown]
# 6) Building SimpleRNN

# %%
def getSimpleRNN(input_shape, lr=0.001, dr=0.2, n_classes=5):

  inp = Input(shape=input_shape)
  img_1 = SimpleRNN(128, activation=None, dropout=dr, return_sequences=True, unroll=True)(inp)
  img_2 = SimpleRNN(256, activation=None, dropout=dr, return_sequences=True, unroll=True)(img_1)
  img_3 = SimpleRNN(100, activation=None, dropout=dr, return_sequences=False, unroll=True)(img_2)
  out = Dense(5, activation='softmax')(img_3)

  model = models.Model(inputs=inp, outputs=out)
  opt = optimizers.Adam(learning_rate=lr)
  model.compile(optimizer=opt, loss=losses.categorical_crossentropy,
                  metrics=['acc'])
  return model

sRNN = getSimpleRNN(X_train[0].shape)
tf.keras.utils.plot_model(sRNN, show_shapes=True, dpi=64)

# %%
# Preparing the model
sRNN_file_path = model_path + "RNN_mit.h5"
checkpoint = ModelCheckpoint(sRNN_file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early = EarlyStopping(monitor='val_loss', mode="min", patience=25, verbose=1)
callbacks_list = [checkpoint, early]

# %%
# Fitting the model
history = sRNN.fit(X_train, Y_train, epochs=1000, verbose=2, callbacks=callbacks_list, batch_size=128, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 0.46442, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNMIT.h5
# 548/548 - 60s - loss: 6.6872 - acc: 0.8001 - val_loss: 0.4644 - val_acc: 0.8731 - 60s/epoch - 109ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.46442 to 0.38989, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNMIT.h5
# 548/548 - 29s - loss: 0.5563 - acc: 0.8475 - val_loss: 0.3899 - val_acc: 0.8820 - 29s/epoch - 54ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.38989 to 0.37219, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNMIT.h5
# 548/548 - 28s - loss: 0.4929 - acc: 0.8614 - val_loss: 0.3722 - val_acc: 0.8856 - 28s/epoch - 51ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.37219
# 548/548 - 28s - loss: 0.4673 - acc: 0.8665 - val_loss: 0.3724 - val_acc: 0.8825 - 28s/epoch - 51ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.37219 to 0.36191, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNMIT.h5
# 548/548 - 27s - loss: 0.4501 - acc: 0.8717 - val_loss: 0.3619 - val_acc: 0.8912 - 27s/epoch - 50ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.36191
# 548/548 - 27s - loss: 0.4415 - acc: 0.8732 - val_loss: 0.3688 - val_acc: 0.8786 - 27s/epoch - 50ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.36191 to 0.34201, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNMIT.h5
# 548/548 - 28s - loss: 0.4323 - acc: 0.8753 - val_loss: 0.3420 - val_acc: 0.8932 - 28s/epoch - 50ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4354 - acc: 0.8746 - val_loss: 0.3571 - val_acc: 0.8941 - 27s/epoch - 50ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4285 - acc: 0.8768 - val_loss: 0.3519 - val_acc: 0.8881 - 27s/epoch - 50ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4251 - acc: 0.8780 - val_loss: 0.3504 - val_acc: 0.8939 - 27s/epoch - 50ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4284 - acc: 0.8774 - val_loss: 0.3560 - val_acc: 0.8846 - 27s/epoch - 49ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4268 - acc: 0.8768 - val_loss: 0.3800 - val_acc: 0.8757 - 27s/epoch - 50ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4318 - acc: 0.8753 - val_loss: 0.4154 - val_acc: 0.8699 - 27s/epoch - 50ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4353 - acc: 0.8750 - val_loss: 0.3904 - val_acc: 0.8883 - 27s/epoch - 50ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4355 - acc: 0.8745 - val_loss: 0.4057 - val_acc: 0.8906 - 27s/epoch - 50ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4502 - acc: 0.8705 - val_loss: 0.3984 - val_acc: 0.8839 - 27s/epoch - 50ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.4809 - acc: 0.8611 - val_loss: 0.4449 - val_acc: 0.8679 - 27s/epoch - 50ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.5353 - acc: 0.8451 - val_loss: 0.5909 - val_acc: 0.8258 - 27s/epoch - 50ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: 0.5790 - acc: 0.8350 - val_loss: 0.5496 - val_acc: 0.8370 - 27s/epoch - 50ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: nan - acc: 0.8252 - val_loss: nan - val_acc: 0.8277 - 27s/epoch - 50ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 27s/epoch - 50ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 27s/epoch - 50ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 27s/epoch - 49ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 27s/epoch - 49ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.34201
# 548/548 - 30s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 30s/epoch - 55ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.34201
# 548/548 - 28s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 28s/epoch - 51ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.34201
# 548/548 - 32s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 32s/epoch - 58ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.34201
# 548/548 - 32s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 32s/epoch - 59ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.34201
# 548/548 - 28s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 28s/epoch - 50ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 0.34201
# 548/548 - 27s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 27s/epoch - 50ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.34201
# 548/548 - 28s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 28s/epoch - 51ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.34201
# 548/548 - 28s - loss: nan - acc: 0.8277 - val_loss: nan - val_acc: 0.8277 - 28s/epoch - 51ms/step
# Epoch 32: early stopping

# %%
# Plot training & validation accuracy values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model CCE')
plt.ylabel('BCE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Analysis of the model
sRNN.load_weights(sRNN_file_path)
Y_pred_test = sRNN.predict(X_test)
cce = tf.keras.losses.CategoricalCrossentropy()
print("Model CCE: {}".format(cce(Y_test,Y_pred_test).numpy()))
m = tf.keras.metrics.Accuracy()
m.update_state(np.argmax(Y_test,axis=1), np.argmax(Y_pred_test,axis=1))
print("Model accuracy: {}".format(m.result().numpy()))
# Out:
# Model CCE: 0.3418559432029724
# Model accuracy: 0.8957153558731079

# %%
# Plotting confusion matrix
cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred_test, axis=1))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2,3])

disp.plot(cmap=plt.cm.Blues)
plt.show()
