# %% [markdown]
# 1) Checking resources

# %%
# !nvidia-smi
# Out:
# Mon Mar 14 15:17:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# 2) Setting up colab

# %%
# Gloabal variables
data_path = "/content/gdrive/My Drive/ETH/MLH/Project1/data/"
model_path = "/content/gdrive/My Drive/ETH/MLH/Project1/model/"

random_seed = 50

# %%
# Mount Google Drive and set data paths.
import os
from google.colab import drive
from google.colab import files

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 3) Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.metrics import roc_auc_score, RocCurveDisplay, average_precision_score, PrecisionRecallDisplay, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, optimizers, losses
from tensorflow.keras.layers import Input, SimpleRNN, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# 4) Loading data

# %%
df_1 = pd.read_csv(data_path + "input/ptbdb_normal.csv", header=None)
df_2 = pd.read_csv(data_path + "input/ptbdb_abnormal.csv", header=None)
df = pd.concat([df_1, df_2])

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1337, stratify=df[187])

Y = np.array(df_train[187].values).astype(np.int8)
X = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

print("X shape is {}".format(X.shape))
print("Y shape is {}".format(Y.shape))
print("X_test shape is {}".format(X_test.shape))
print("Y_test shape is {}".format(Y_test.shape))
# Out:
# X shape is (11641, 187, 1)
# Y shape is (11641,)
# X_test shape is (2911, 187, 1)
# Y_test shape is (2911,)

# %% [markdown]
# 5) Visualizing data

# %%
# Plotting one signal
example_signal = 56
plt.rcParams['lines.linewidth'] = 3
plt.figure(figsize=(30, 11))
plt.plot(X[example_signal])
plt.title("ECG number {} - Class: {}".format(example_signal+1, Y[example_signal]), size = 20)
plt.show()

# %% [markdown]
# 6) Creating validation set

# %%
# Splitting dataset for validation
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=random_seed)
for train_index, test_index in sss.split(X, Y):
    X_train, X_val = X[train_index], X[test_index]
    Y_train, Y_val = Y[train_index], Y[test_index]

print("X_train shape is {}".format(X_train.shape))
print("Y_train shape is {}".format(Y_train.shape))
print("X_val shape is {}".format(X_val.shape))
print("Y_val shape is {}".format(Y_val.shape))
# Out:
# X_train shape is (9312, 187, 1)
# Y_train shape is (9312,)
# X_val shape is (2329, 187, 1)
# Y_val shape is (2329,)

# %% [markdown]
# 6) Building SimpleRNN

# %%
def getSimpleRNN(input_shape, lr=0.001, dr=0.2):

  inp = Input(shape=input_shape)
  img_1 = SimpleRNN(128, activation=None, dropout=dr, return_sequences=True, unroll=True)(inp)
  img_2 = SimpleRNN(256, activation=None, dropout=dr, return_sequences=True, unroll=True)(img_1)
  img_3 = SimpleRNN(100, activation=None, dropout=dr, return_sequences=False, unroll=True)(img_2)
  out = Dense(1, activation='sigmoid', use_bias=True)(img_3)

  model = models.Model(inputs=inp, outputs=out)
  opt = optimizers.Adam(learning_rate=lr)
  model.compile(optimizer=opt, loss=losses.BinaryCrossentropy(name='bce', from_logits=False), metrics=['bce'])
  
  return model

sRNN = getSimpleRNN(X_train[0].shape)
tf.keras.utils.plot_model(sRNN, show_shapes=True, dpi=64)

# %%
# Preparing the model
sRNN_file_path = model_path + "simpleRNNBinary.h5"
checkpoint = ModelCheckpoint(sRNN_file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early = EarlyStopping(monitor='val_loss', mode="min", patience=25, verbose=1)
callbacks_list = [checkpoint, early]

# %%
# Fitting the model
history = sRNN.fit(X_train, Y_train, epochs=1000, verbose=2, callbacks=callbacks_list, batch_size=128, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 0.48160, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 48s - loss: 6.8283 - bce: 6.8283 - val_loss: 0.4816 - val_bce: 0.4816 - 48s/epoch - 651ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.48160 to 0.45887, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 7s - loss: 0.5931 - bce: 0.5931 - val_loss: 0.4589 - val_bce: 0.4589 - 7s/epoch - 99ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.45887 to 0.44536, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 8s - loss: 0.5383 - bce: 0.5383 - val_loss: 0.4454 - val_bce: 0.4454 - 8s/epoch - 114ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.44536
# 73/73 - 5s - loss: 0.5192 - bce: 0.5192 - val_loss: 0.4674 - val_bce: 0.4674 - 5s/epoch - 65ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.44536 to 0.43156, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 6s - loss: 0.5006 - bce: 0.5006 - val_loss: 0.4316 - val_bce: 0.4316 - 6s/epoch - 81ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.43156
# 73/73 - 5s - loss: 0.4901 - bce: 0.4901 - val_loss: 0.4657 - val_bce: 0.4657 - 5s/epoch - 65ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.43156
# 73/73 - 5s - loss: 0.4896 - bce: 0.4896 - val_loss: 0.4380 - val_bce: 0.4380 - 5s/epoch - 65ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.43156
# 73/73 - 5s - loss: 0.4866 - bce: 0.4866 - val_loss: 0.4408 - val_bce: 0.4408 - 5s/epoch - 65ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 0.43156 to 0.42474, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 5s - loss: 0.4854 - bce: 0.4854 - val_loss: 0.4247 - val_bce: 0.4247 - 5s/epoch - 73ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.42474
# 73/73 - 5s - loss: 0.4849 - bce: 0.4849 - val_loss: 0.4255 - val_bce: 0.4255 - 5s/epoch - 65ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.42474
# 73/73 - 5s - loss: 0.4846 - bce: 0.4846 - val_loss: 0.4404 - val_bce: 0.4404 - 5s/epoch - 65ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.42474
# 73/73 - 5s - loss: 0.4751 - bce: 0.4751 - val_loss: 0.4349 - val_bce: 0.4349 - 5s/epoch - 64ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.42474
# 73/73 - 5s - loss: 0.4779 - bce: 0.4779 - val_loss: 0.4338 - val_bce: 0.4338 - 5s/epoch - 65ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 0.42474 to 0.41990, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 5s - loss: 0.4755 - bce: 0.4755 - val_loss: 0.4199 - val_bce: 0.4199 - 5s/epoch - 72ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss improved from 0.41990 to 0.41413, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/simpleRNNBinary.h5
# 73/73 - 5s - loss: 0.4688 - bce: 0.4688 - val_loss: 0.4141 - val_bce: 0.4141 - 5s/epoch - 65ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4804 - bce: 0.4804 - val_loss: 0.4542 - val_bce: 0.4542 - 5s/epoch - 70ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4768 - bce: 0.4768 - val_loss: 0.4441 - val_bce: 0.4441 - 5s/epoch - 67ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4679 - bce: 0.4679 - val_loss: 0.4334 - val_bce: 0.4334 - 5s/epoch - 64ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4722 - bce: 0.4722 - val_loss: 0.4276 - val_bce: 0.4276 - 5s/epoch - 64ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4681 - bce: 0.4681 - val_loss: 0.4175 - val_bce: 0.4175 - 5s/epoch - 64ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4657 - bce: 0.4657 - val_loss: 0.4208 - val_bce: 0.4208 - 5s/epoch - 65ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4651 - bce: 0.4651 - val_loss: 0.4479 - val_bce: 0.4479 - 5s/epoch - 64ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4732 - bce: 0.4732 - val_loss: 0.4349 - val_bce: 0.4349 - 5s/epoch - 64ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4718 - bce: 0.4718 - val_loss: 0.4336 - val_bce: 0.4336 - 5s/epoch - 64ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4657 - bce: 0.4657 - val_loss: 0.4280 - val_bce: 0.4280 - 5s/epoch - 64ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4624 - bce: 0.4624 - val_loss: 0.4205 - val_bce: 0.4205 - 5s/epoch - 65ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4718 - bce: 0.4718 - val_loss: 0.4535 - val_bce: 0.4535 - 5s/epoch - 64ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4728 - bce: 0.4728 - val_loss: 0.4206 - val_bce: 0.4206 - 5s/epoch - 65ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4727 - bce: 0.4727 - val_loss: 0.4177 - val_bce: 0.4177 - 5s/epoch - 65ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4699 - bce: 0.4699 - val_loss: 0.4262 - val_bce: 0.4262 - 5s/epoch - 64ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4730 - bce: 0.4730 - val_loss: 0.4381 - val_bce: 0.4381 - 5s/epoch - 65ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4716 - bce: 0.4716 - val_loss: 0.4361 - val_bce: 0.4361 - 5s/epoch - 65ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4717 - bce: 0.4717 - val_loss: 0.4217 - val_bce: 0.4217 - 5s/epoch - 64ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4671 - bce: 0.4671 - val_loss: 0.4224 - val_bce: 0.4224 - 5s/epoch - 64ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4625 - bce: 0.4625 - val_loss: 0.4470 - val_bce: 0.4470 - 5s/epoch - 65ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4707 - bce: 0.4707 - val_loss: 0.4309 - val_bce: 0.4309 - 5s/epoch - 64ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4762 - bce: 0.4762 - val_loss: 0.4431 - val_bce: 0.4431 - 5s/epoch - 64ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4652 - bce: 0.4652 - val_loss: 0.4473 - val_bce: 0.4473 - 5s/epoch - 64ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4663 - bce: 0.4663 - val_loss: 0.4226 - val_bce: 0.4226 - 5s/epoch - 64ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.41413
# 73/73 - 5s - loss: 0.4823 - bce: 0.4823 - val_loss: 0.4504 - val_bce: 0.4504 - 5s/epoch - 64ms/step
# Epoch 40: early stopping

# %%
# Analysis of the model
sRNN.load_weights(sRNN_file_path)
Y_pred_test = sRNN.predict(X_test)
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
print("Model BCE: {}".format(bce(Y_test,Y_pred_test.flatten()).numpy()))
m = tf.keras.metrics.Accuracy()
m.update_state(Y_test.reshape(-1,1), Y_pred_test > 0.5)
print("Model accuracy: {}".format(m.result().numpy()))
# Out:
# Model BCE: 0.5413889288902283
# Model accuracy: 0.7925111651420593

# %%
RocCurveDisplay.from_predictions(Y_test.reshape(-1,1), Y_pred_test)
print("Model AUROC: {}".format(roc_auc_score(Y_test.reshape(-1,1), Y_pred_test, average=None)))
# Out:
# Model AUROC: 0.8577568717296729

# %%
PrecisionRecallDisplay.from_predictions(Y_test.reshape(-1,1), Y_pred_test)
print("Model AUPRC: {}".format(average_precision_score(Y_test.reshape(-1,1), Y_pred_test)))
# Out:
# Model AUPRC: 0.9411417354749054

# %%
# Plot training & validation accuracy values
plt.plot(history.history['bce'])
plt.plot(history.history['val_bce'])
plt.title('Model BCE')
plt.ylabel('BCE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
