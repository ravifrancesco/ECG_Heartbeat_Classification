# %% [markdown]
# Notebook parameters

# %%
use_tpu = False
train = True

# %% [markdown]
# 1) Checking resources

# %%
if use_tpu:
  # %tensorflow_version 2.x
  import tensorflow as tf
  print("Tensorflow version " + tf.__version__)

  try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
  except ValueError:
    raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

  tf.config.experimental_connect_to_cluster(tpu)
  tf.tpu.experimental.initialize_tpu_system(tpu)
  tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# 2) Setting up colab

# %%
# Gloabal variables
data_path = "/content/gdrive/My Drive/ETH/MLH/Project1/data/"
model_path = "/content/gdrive/My Drive/ETH/MLH/Project1/model/"

random_seed = 50

# %%
# Mount Google Drive and set data paths.
import os
from google.colab import drive
from google.colab import files

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 3) Imports

# %%
import pandas as pd
import numpy as np
import itertools

import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score, RocCurveDisplay, average_precision_score, PrecisionRecallDisplay, auc


from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

from collections import Counter

import pywt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, optimizers, losses
from tensorflow.keras.layers import Input, LSTM, Dense, Bidirectional, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16477749263273270579
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14465892352
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9839188591219574339
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# Default GPU Device: /device:GPU:0

# %% [markdown]
# 4) Loading data

# %%
df_1 = pd.read_csv(data_path + "input/ptbdb_normal.csv", header=None)
df_2 = pd.read_csv(data_path + "input/ptbdb_abnormal.csv", header=None)
df = pd.concat([df_1, df_2])

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1337, stratify=df[187])

Y_train = np.array(df_train[187].values).astype(np.int8)
X_train = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

print("X_train shape is {}".format(X_train.shape))
print("Y_train shape is {}".format(Y_train.shape))
print("X_test shape is {}".format(X_test.shape))
print("Y_test shape is {}".format(Y_test.shape))
# Out:
# X_train shape is (11641, 187, 1)
# Y_train shape is (11641,)
# X_test shape is (2911, 187, 1)
# Y_test shape is (2911,)

# %%
X_train = np.squeeze(X_train)
Y_train = np.squeeze(Y_train)
X_test = np.squeeze(X_test)
Y_test = np.squeeze(Y_test)

print("X_train shape is {}".format(X_train.shape))
print("Y_train shape is {}".format(Y_train.shape))
print("X_test shape is {}".format(X_test.shape))
print("Y_test shape is {}".format(Y_test.shape))
# Out:
# X_train shape is (11641, 187)
# Y_train shape is (11641,)
# X_test shape is (2911, 187)
# Y_test shape is (2911,)

# %% [markdown]
# 5) Visualizing data

# %%
# Plotting one signal
example_signal = 56
plt.rcParams['lines.linewidth'] = 3
plt.figure(figsize=(30, 11))
plt.plot(X_train[example_signal])
plt.title("ECG number {} - Class: {}".format(example_signal+1, Y_train[example_signal]), size = 20)
plt.show()

# %% [markdown]
# 6) Building SimpleRNN

# %%
# Discrete wavelet transform multiresolution analysis level by level
coeffs = pywt.wavedec(X_train[example_signal].flatten(), 'db6', mode='symmetric', level=4)[1:]

fig, axs = plt.subplots(4, figsize=(20, 13))
fig.suptitle("ECG number {} - Class: {}".format(example_signal+1, Y_train[example_signal]), size=20)
for i, c in enumerate(coeffs):
  axs[i].plot(c)
  axs[i].set_title("Level {}".format(str(4-i)))

# %%
def DWT(signal, levels):
  coeffs = pywt.wavedec(signal.flatten(), 'db6', mode='symmetric', level=levels)[1:]
  coeffs = [np.pad(np.array(c), (0, 187-len(c))) for c in coeffs]
  coeffs += [signal]
  return np.stack(coeffs, axis=-1)

def WSpreprocess(dataset, levels):
  return np.squeeze(np.apply_along_axis(DWT, 1, dataset, levels))

# %%
X_train = WSpreprocess(X_train, 2)
#X_val = WSpreprocess(X_val, 2)
X_test = WSpreprocess(X_test, 2)

print("X_train shape is {}".format(X_train.shape))
#print("X_val shape is {}".format(X_val.shape))
print("X_test shape is {}".format(X_test.shape))
# Out:
# X_train shape is (11641, 187, 3)
# X_test shape is (2911, 187, 3)

# %%
def getDBLSTMWS(input_shape, lr=0.0005, n_classes=1, loss=losses.BinaryCrossentropy(from_logits=False)):

  inp = Input(shape=input_shape)
  img_1 = Bidirectional(LSTM(64, return_sequences=True))(inp)
  img_2 = Dropout(0.01)(img_1)
  img_3 = Bidirectional(LSTM(32, return_sequences=True))(img_2)
  img_4 = Dropout(0.01)(img_3)
  img_5 = Flatten()(img_4)
  img_6 = Dense(128, activation='relu')(img_5) #, name='dense_binary')(img_5)
  img_7 = Dropout(0.3)(img_6)
  out = Dense(n_classes, activation='sigmoid', name='out_binary')(img_7)

  model = models.Model(inputs=inp, outputs=out)
  opt = optimizers.Adam(learning_rate=lr)
  model.compile(optimizer=opt, loss=loss,
                  metrics=['acc'])
  return model

# %%
if use_tpu:
  with tpu_strategy.scope():
    sRNN = getDBLSTMWS(X_train[0].shape, lr=0.001)
else:
    sRNN = getDBLSTMWS(X_train[0].shape, lr=0.001)
    
tf.keras.utils.plot_model(sRNN, show_shapes=True, dpi=64)

# %%
# Preparing the model
sRNN_file_path = model_path + "DBLSTM-WS_mit_tl.h5"
checkpoint = ModelCheckpoint(sRNN_file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early = EarlyStopping(monitor='val_loss', mode="min", patience=10, verbose=1)
redonplat = ReduceLROnPlateau(monitor='val_loss', mode="min", patience=5, verbose=2)
callbacks_list = [early, checkpoint, redonplat]

# %%
# Freezing layers for transfer learning
sRNN.load_weights(model_path + "DBLSTM-WS_mit.h5", by_name=True)
sRNN.get_layer('bidirectional').trainable = False
sRNN.get_layer('bidirectional_1').trainable = False
#sRNN.get_layer('dense').trainable = False
sRNN.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 187, 3)]          0
#
#  bidirectional (Bidirectiona  (None, 187, 128)         34816
#  l)
#
#  dropout (Dropout)           (None, 187, 128)          0
#
#  bidirectional_1 (Bidirectio  (None, 187, 64)          41216
#  nal)
#
#  dropout_1 (Dropout)         (None, 187, 64)           0
#
#  flatten (Flatten)           (None, 11968)             0
#
#  dense (Dense)               (None, 128)               1532032
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  out_binary (Dense)          (None, 1)                 129
#
# =================================================================
# Total params: 1,608,193
# Trainable params: 1,532,161
# Non-trainable params: 76,032
# _________________________________________________________________

# %%
# Fitting the model
if train:
  history = sRNN.fit(X_train, Y_train, epochs=1000, verbose=2, callbacks=callbacks_list, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 0.22829, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 13s - loss: 0.4494 - acc: 0.8171 - val_loss: 0.2283 - val_acc: 0.9051 - lr: 0.0010 - 13s/epoch - 179ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.22829 to 0.14360, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.1929 - acc: 0.9215 - val_loss: 0.1436 - val_acc: 0.9429 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.14360 to 0.09700, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.1271 - acc: 0.9477 - val_loss: 0.0970 - val_acc: 0.9648 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.09700 to 0.07980, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0960 - acc: 0.9640 - val_loss: 0.0798 - val_acc: 0.9717 - lr: 0.0010 - 3s/epoch - 39ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.07980 to 0.06996, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0735 - acc: 0.9727 - val_loss: 0.0700 - val_acc: 0.9747 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.06996 to 0.06076, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0527 - acc: 0.9834 - val_loss: 0.0608 - val_acc: 0.9794 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.06076 to 0.05426, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0473 - acc: 0.9825 - val_loss: 0.0543 - val_acc: 0.9820 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 0.05426 to 0.04619, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0447 - acc: 0.9845 - val_loss: 0.0462 - val_acc: 0.9811 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.04619
# 73/73 - 3s - loss: 0.0352 - acc: 0.9879 - val_loss: 0.0576 - val_acc: 0.9841 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 0.04619 to 0.03928, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0360 - acc: 0.9872 - val_loss: 0.0393 - val_acc: 0.9888 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.03928
# 73/73 - 3s - loss: 0.0240 - acc: 0.9917 - val_loss: 0.0394 - val_acc: 0.9858 - lr: 0.0010 - 3s/epoch - 40ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss improved from 0.03928 to 0.03547, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0210 - acc: 0.9928 - val_loss: 0.0355 - val_acc: 0.9893 - lr: 0.0010 - 3s/epoch - 38ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.03547
# 73/73 - 3s - loss: 0.0181 - acc: 0.9939 - val_loss: 0.0420 - val_acc: 0.9871 - lr: 0.0010 - 3s/epoch - 38ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.03547
# 73/73 - 3s - loss: 0.0216 - acc: 0.9928 - val_loss: 0.0417 - val_acc: 0.9871 - lr: 0.0010 - 3s/epoch - 35ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.03547
# 73/73 - 3s - loss: 0.0257 - acc: 0.9900 - val_loss: 0.0369 - val_acc: 0.9888 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.03547
# 73/73 - 3s - loss: 0.0152 - acc: 0.9945 - val_loss: 0.0373 - val_acc: 0.9888 - lr: 0.0010 - 3s/epoch - 38ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss improved from 0.03547 to 0.02825, saving model to /content/gdrive/My Drive/ETH/MLH/Project1/model/DBLSTM-WS_mit_tl.h5
# 73/73 - 3s - loss: 0.0122 - acc: 0.9956 - val_loss: 0.0283 - val_acc: 0.9901 - lr: 0.0010 - 3s/epoch - 44ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0124 - acc: 0.9958 - val_loss: 0.0441 - val_acc: 0.9884 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0117 - acc: 0.9955 - val_loss: 0.0344 - val_acc: 0.9906 - lr: 0.0010 - 3s/epoch - 38ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0088 - acc: 0.9976 - val_loss: 0.0400 - val_acc: 0.9914 - lr: 0.0010 - 3s/epoch - 37ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0153 - acc: 0.9945 - val_loss: 0.0385 - val_acc: 0.9906 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.02825
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 73/73 - 3s - loss: 0.0145 - acc: 0.9954 - val_loss: 0.0346 - val_acc: 0.9893 - lr: 0.0010 - 3s/epoch - 36ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0093 - acc: 0.9969 - val_loss: 0.0307 - val_acc: 0.9893 - lr: 1.0000e-04 - 3s/epoch - 36ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0060 - acc: 0.9983 - val_loss: 0.0314 - val_acc: 0.9901 - lr: 1.0000e-04 - 3s/epoch - 36ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0049 - acc: 0.9984 - val_loss: 0.0321 - val_acc: 0.9901 - lr: 1.0000e-04 - 3s/epoch - 39ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.02825
# 73/73 - 3s - loss: 0.0045 - acc: 0.9988 - val_loss: 0.0353 - val_acc: 0.9923 - lr: 1.0000e-04 - 3s/epoch - 37ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.02825
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 73/73 - 3s - loss: 0.0042 - acc: 0.9986 - val_loss: 0.0334 - val_acc: 0.9918 - lr: 1.0000e-04 - 3s/epoch - 36ms/step
# Epoch 27: early stopping

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model BCE')
plt.ylabel('BCE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Analysis of the model
sRNN.load_weights(sRNN_file_path)
Y_pred_test = sRNN.predict(X_test)
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
print("Model BCE: {}".format(bce(Y_test,Y_pred_test.flatten()).numpy()))
m = tf.keras.metrics.Accuracy()
m.update_state(Y_test.reshape(-1,1), Y_pred_test > 0.5)
print("Model accuracy: {}".format(m.result().numpy()))
# Out:
# Model BCE: 0.4237106740474701
# Model accuracy: 0.9927859902381897

# %%
RocCurveDisplay.from_predictions(Y_test.reshape(-1,1), Y_pred_test)
print("Model AUROC: {}".format(roc_auc_score(Y_test.reshape(-1,1), Y_pred_test, average=None)))
# Out:
# Model AUROC: 0.996953869350398

# %%
PrecisionRecallDisplay.from_predictions(Y_test.reshape(-1,1), Y_pred_test)
print("Model AUPRC: {}".format(average_precision_score(Y_test.reshape(-1,1), Y_pred_test)))
# Out:
# Model AUPRC: 0.997703726362919
